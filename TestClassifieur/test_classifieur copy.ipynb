# %%
import pandas as pd
import torch
import torch.nn as nn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Configure testcase
form = "Cat"
num_config = 2
nb_vert = 200

filename = form+"_lv"+str(num_config)+"_"+str(nb_vert)+"_all.csv"
filename = "masks/" + filename

# %%
# Read data
data = pd.read_csv(filename) #, header=None)
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

X = torch.tensor(X.values, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
class Deep(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(2, 60)
        self.act1 = nn.ReLU()
        self.layer2 = nn.Linear(60, 60)
        self.act2 = nn.ReLU()
        self.layer3 = nn.Linear(60, 60)
        self.act3 = nn.ReLU()
        self.output = nn.Linear(60, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.act1(self.layer1(x))
        x = self.act2(self.layer2(x))
        x = self.act3(self.layer3(x))
        x = self.sigmoid(self.output(x))
        return x

# %%
# Compare model sizes
model1 = Deep()
print(sum([x.reshape(-1).shape[0] for x in model1.parameters()]))  # 11161
# Out:
# 7561

# %%
import copy
import numpy as np
import torch.optim as optim
import tqdm

def model_train(model, X_train, y_train, X_val, y_val):
    # loss function and optimizer
    loss_fn = nn.BCELoss()  # binary cross entropy
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    n_epochs = 250   # number of epochs to run
    batch_size = 10  # size of each batch
    batch_start = torch.arange(0, len(X_train), batch_size)

    # Hold the best model
    best_acc = - np.inf   # init to negative infinity
    best_weights = None

    for epoch in range(n_epochs):
        model.train()
        with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
            bar.set_description(f"Epoch {epoch}")
            for start in bar:
                # take a batch
                X_batch = X_train[start:start+batch_size]
                y_batch = y_train[start:start+batch_size]
                # forward pass
                y_pred = model(X_batch)
                loss = loss_fn(y_pred, y_batch)
                # backward pass
                optimizer.zero_grad()
                loss.backward()
                # update weights
                optimizer.step()
                # print progress
                acc = (y_pred.round() == y_batch).float().mean()
                bar.set_postfix(
                    loss=float(loss),
                    acc=float(acc)
                )
        # evaluate accuracy at end of each epoch
        model.eval()
        y_pred = model(X_val)
        acc = (y_pred.round() == y_val).float().mean()
        acc = float(acc)
        if acc > best_acc:
            best_acc = acc
            best_weights = copy.deepcopy(model.state_dict())
        print(f"Epochs {epoch}: accuracy = {acc:.4f}")
    # restore model and return best accuracy
    model.load_state_dict(best_weights)
    return best_acc

# %%
from sklearn.model_selection import StratifiedKFold, train_test_split

# train-test split: Hold out the test set for final model evaluation
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True)

# define 5-fold cross validation test harness
kfold = StratifiedKFold(n_splits=5, shuffle=True)
cv_scores_wide = []
for train, test in kfold.split(X_train, y_train):
    # create model, train, and get accuracy
    model = Deep()
    acc = model_train(model, X_train[train], y_train[train], X_train[test], y_train[test])
    print("Accuracy (wide): %.2f" % acc)
    cv_scores_wide.append(acc)

# evaluate the model
wide_acc = np.mean(cv_scores_wide)
wide_std = np.std(cv_scores_wide)
print("Wide: %.2f%% (+/- %.2f%%)" % (wide_acc*100, wide_std*100))
# Out:
# Epochs 0: accuracy = 0.8880
# Epochs 1: accuracy = 0.8936
# Epochs 2: accuracy = 0.9000
# Epochs 3: accuracy = 0.9062
# Epochs 4: accuracy = 0.9109
# Epochs 5: accuracy = 0.9177
# Epochs 6: accuracy = 0.9214
# Epochs 7: accuracy = 0.9254
# Epochs 8: accuracy = 0.9284
# Epochs 9: accuracy = 0.9325
# Epochs 10: accuracy = 0.9357
# Epochs 11: accuracy = 0.9400
# Epochs 12: accuracy = 0.9420
# Epochs 13: accuracy = 0.9434
# Epochs 14: accuracy = 0.9450
# Epochs 15: accuracy = 0.9466
# Epochs 16: accuracy = 0.9488
# Epochs 17: accuracy = 0.9493
# Epochs 18: accuracy = 0.9495
# Epochs 19: accuracy = 0.9504
# Epochs 20: accuracy = 0.9520
# Epochs 21: accuracy = 0.9539
# Epochs 22: accuracy = 0.9550
# Epochs 23: accuracy = 0.9557
# Epochs 24: accuracy = 0.9566
# Epochs 25: accuracy = 0.9577
# Epochs 26: accuracy = 0.9584
# Epochs 27: accuracy = 0.9593
# Epochs 28: accuracy = 0.9600
# Epochs 29: accuracy = 0.9602
# Epochs 30: accuracy = 0.9605
# Epochs 31: accuracy = 0.9613
# Epochs 32: accuracy = 0.9616
# Epochs 33: accuracy = 0.9625
# Epochs 34: accuracy = 0.9627
# Epochs 35: accuracy = 0.9632
# Epochs 36: accuracy = 0.9636
# Epochs 37: accuracy = 0.9646
# Epochs 38: accuracy = 0.9648
# Epochs 39: accuracy = 0.9648
# Epochs 40: accuracy = 0.9650
# Epochs 41: accuracy = 0.9655
# Epochs 42: accuracy = 0.9654
# Epochs 43: accuracy = 0.9659
# Epochs 44: accuracy = 0.9663
# Epochs 45: accuracy = 0.9670
# Epochs 46: accuracy = 0.9666
# Epochs 47: accuracy = 0.9664
# Epochs 48: accuracy = 0.9670
# Epochs 49: accuracy = 0.9671
# Epochs 50: accuracy = 0.9675
# Epochs 51: accuracy = 0.9679
# Epochs 52: accuracy = 0.9680
# Epochs 53: accuracy = 0.9684
# Epochs 54: accuracy = 0.9684
# Epochs 55: accuracy = 0.9684
# Epochs 56: accuracy = 0.9688
# Epochs 57: accuracy = 0.9689
# Epochs 58: accuracy = 0.9689
# Epochs 59: accuracy = 0.9688
# Epochs 60: accuracy = 0.9693
# Epochs 61: accuracy = 0.9693
# Epochs 62: accuracy = 0.9695
# Epochs 63: accuracy = 0.9695
# Epochs 64: accuracy = 0.9693
# Epochs 65: accuracy = 0.9693
# Epochs 66: accuracy = 0.9695
# Epochs 67: accuracy = 0.9698
# Epochs 68: accuracy = 0.9705
# Epochs 69: accuracy = 0.9705
# Epochs 70: accuracy = 0.9705
# Epochs 71: accuracy = 0.9704
# Epochs 72: accuracy = 0.9707
# Epochs 73: accuracy = 0.9707
# Epochs 74: accuracy = 0.9707
# Epochs 75: accuracy = 0.9709
# Epochs 76: accuracy = 0.9709
# Epochs 77: accuracy = 0.9709
# Epochs 78: accuracy = 0.9707
# Epochs 79: accuracy = 0.9707
# Epochs 80: accuracy = 0.9709
# Epochs 81: accuracy = 0.9709
# Epochs 82: accuracy = 0.9711
# Epochs 83: accuracy = 0.9709
# Epochs 84: accuracy = 0.9712
# Epochs 85: accuracy = 0.9714
# Epochs 86: accuracy = 0.9714
# Epochs 87: accuracy = 0.9714
# Epochs 88: accuracy = 0.9716
# Epochs 89: accuracy = 0.9718
# Epochs 90: accuracy = 0.9718
# Epochs 91: accuracy = 0.9718
# Epochs 92: accuracy = 0.9720
# Epochs 93: accuracy = 0.9721
# Epochs 94: accuracy = 0.9721
# Epochs 95: accuracy = 0.9727
# Epochs 96: accuracy = 0.9725
# Epochs 97: accuracy = 0.9727
# Epochs 98: accuracy = 0.9729
# Epochs 99: accuracy = 0.9727
# Epochs 100: accuracy = 0.9730
# Epochs 101: accuracy = 0.9732
# Epochs 102: accuracy = 0.9732
# Epochs 103: accuracy = 0.9730
# Epochs 104: accuracy = 0.9732
# Epochs 105: accuracy = 0.9730
# Epochs 106: accuracy = 0.9730
# Epochs 107: accuracy = 0.9729
# Epochs 108: accuracy = 0.9730
# Epochs 109: accuracy = 0.9727
# Epochs 110: accuracy = 0.9729
# Epochs 111: accuracy = 0.9730
# Epochs 112: accuracy = 0.9732
# Epochs 113: accuracy = 0.9734
# Epochs 114: accuracy = 0.9732
# Epochs 115: accuracy = 0.9736
# Epochs 116: accuracy = 0.9732
# Epochs 117: accuracy = 0.9732
# Epochs 118: accuracy = 0.9730
# Epochs 119: accuracy = 0.9732
# Epochs 120: accuracy = 0.9736
# Epochs 121: accuracy = 0.9734
# Epochs 122: accuracy = 0.9734
# Epochs 123: accuracy = 0.9732
# Epochs 124: accuracy = 0.9734
# Epochs 125: accuracy = 0.9737
# Epochs 126: accuracy = 0.9732
# Epochs 127: accuracy = 0.9730
# Epochs 128: accuracy = 0.9730
# Epochs 129: accuracy = 0.9734
# Epochs 130: accuracy = 0.9730
# Epochs 131: accuracy = 0.9734
# Epochs 132: accuracy = 0.9736
# Epochs 133: accuracy = 0.9732
# Epochs 134: accuracy = 0.9736
# Epochs 135: accuracy = 0.9737
# Epochs 136: accuracy = 0.9737
# Epochs 137: accuracy = 0.9737
# Epochs 138: accuracy = 0.9739
# Epochs 139: accuracy = 0.9734
# Epochs 140: accuracy = 0.9739
# Epochs 141: accuracy = 0.9739
# Epochs 142: accuracy = 0.9739
# Epochs 143: accuracy = 0.9741
# Epochs 144: accuracy = 0.9743
# Epochs 145: accuracy = 0.9746
# Epochs 146: accuracy = 0.9746
# Epochs 147: accuracy = 0.9746
# Epochs 148: accuracy = 0.9748
# Epochs 149: accuracy = 0.9746
# Epochs 150: accuracy = 0.9748
# Epochs 151: accuracy = 0.9746
# Epochs 152: accuracy = 0.9746
# Epochs 153: accuracy = 0.9748
# Epochs 154: accuracy = 0.9745
# Epochs 155: accuracy = 0.9757
# Epochs 156: accuracy = 0.9752
# Epochs 157: accuracy = 0.9752
# Epochs 158: accuracy = 0.9752
# Epochs 159: accuracy = 0.9755
# Epochs 160: accuracy = 0.9752
# Epochs 161: accuracy = 0.9757
# Epochs 162: accuracy = 0.9752
# Epochs 163: accuracy = 0.9757
# Epochs 164: accuracy = 0.9752
# Epochs 165: accuracy = 0.9752
# Epochs 166: accuracy = 0.9754
# Epochs 167: accuracy = 0.9754
# Epochs 168: accuracy = 0.9752
# Epochs 169: accuracy = 0.9755
# Epochs 170: accuracy = 0.9754
# Epochs 171: accuracy = 0.9754
# Epochs 172: accuracy = 0.9755
# Epochs 173: accuracy = 0.9759
# Epochs 174: accuracy = 0.9761
# Epochs 175: accuracy = 0.9757
# Epochs 176: accuracy = 0.9762
# Epochs 177: accuracy = 0.9762
# Epochs 178: accuracy = 0.9762
# Epochs 179: accuracy = 0.9762
# Epochs 180: accuracy = 0.9764
# Epochs 181: accuracy = 0.9764
# Epochs 182: accuracy = 0.9764
# Epochs 183: accuracy = 0.9766
# Epochs 184: accuracy = 0.9764
# Epochs 185: accuracy = 0.9766
# Epochs 186: accuracy = 0.9768
# Epochs 187: accuracy = 0.9770
# Epochs 188: accuracy = 0.9770
# Epochs 189: accuracy = 0.9770
# Epochs 190: accuracy = 0.9770
# Epochs 191: accuracy = 0.9764
# Epochs 192: accuracy = 0.9764
# Epochs 193: accuracy = 0.9770
# Epochs 194: accuracy = 0.9768
# Epochs 195: accuracy = 0.9768
# Epochs 196: accuracy = 0.9770
# Epochs 197: accuracy = 0.9768
# Epochs 198: accuracy = 0.9768
# Epochs 199: accuracy = 0.9771
# Epochs 200: accuracy = 0.9771
# Epochs 201: accuracy = 0.9770
# Epochs 202: accuracy = 0.9771
# Epochs 203: accuracy = 0.9771
# Epochs 204: accuracy = 0.9771
# Epochs 205: accuracy = 0.9768
# Epochs 206: accuracy = 0.9770
# Epochs 207: accuracy = 0.9766
# Epochs 208: accuracy = 0.9770
# Epochs 209: accuracy = 0.9773
# Epochs 210: accuracy = 0.9770
# Epochs 211: accuracy = 0.9773
# Epochs 212: accuracy = 0.9773
# Epochs 213: accuracy = 0.9775
# Epochs 214: accuracy = 0.9777
# Epochs 215: accuracy = 0.9775
# Epochs 216: accuracy = 0.9775
# Epochs 217: accuracy = 0.9779
# Epochs 218: accuracy = 0.9775
# Epochs 219: accuracy = 0.9780
# Epochs 220: accuracy = 0.9777
# Epochs 221: accuracy = 0.9779
# Epochs 222: accuracy = 0.9780
# Epochs 223: accuracy = 0.9779
# Epochs 224: accuracy = 0.9780
# Epochs 225: accuracy = 0.9780
# Epochs 226: accuracy = 0.9782
# Epochs 227: accuracy = 0.9779
# Epochs 228: accuracy = 0.9782
# Epochs 229: accuracy = 0.9782
# Epochs 230: accuracy = 0.9782
# Epochs 231: accuracy = 0.9784
# Epochs 232: accuracy = 0.9784
# Epochs 233: accuracy = 0.9784
# Epochs 234: accuracy = 0.9786
# Epochs 235: accuracy = 0.9782
# Epochs 236: accuracy = 0.9784
# Epochs 237: accuracy = 0.9784
# Epochs 238: accuracy = 0.9780
# Epochs 239: accuracy = 0.9784
# Epochs 240: accuracy = 0.9787
# Epochs 241: accuracy = 0.9787
# Epochs 242: accuracy = 0.9787
# Epochs 243: accuracy = 0.9787
# Epochs 244: accuracy = 0.9791
# Epochs 245: accuracy = 0.9789
# Epochs 246: accuracy = 0.9791
# Epochs 247: accuracy = 0.9789
# Epochs 248: accuracy = 0.9791
# Epochs 249: accuracy = 0.9791
# Accuracy (wide): 0.98
# Epochs 0: accuracy = 0.8763
# Epochs 1: accuracy = 0.8839
# Epochs 2: accuracy = 0.8934
# Epochs 3: accuracy = 0.9036
# Epochs 4: accuracy = 0.9112
# Epochs 5: accuracy = 0.9159
# Epochs 6: accuracy = 0.9184
# Epochs 7: accuracy = 0.9214
# Epochs 8: accuracy = 0.9255
# Epochs 9: accuracy = 0.9302
# Epochs 10: accuracy = 0.9325
# Epochs 11: accuracy = 0.9361
# Epochs 12: accuracy = 0.9402
# Epochs 13: accuracy = 0.9439
# Epochs 14: accuracy = 0.9450
# Epochs 15: accuracy = 0.9471
# Epochs 16: accuracy = 0.9482
# Epochs 17: accuracy = 0.9493
# Epochs 18: accuracy = 0.9505
# Epochs 19: accuracy = 0.9516
# Epochs 20: accuracy = 0.9539
# Epochs 21: accuracy = 0.9559
# Epochs 22: accuracy = 0.9566
# Epochs 23: accuracy = 0.9575
# Epochs 24: accuracy = 0.9593
# Epochs 25: accuracy = 0.9600
# Epochs 26: accuracy = 0.9611
# Epochs 27: accuracy = 0.9613
# Epochs 28: accuracy = 0.9611
# Epochs 29: accuracy = 0.9620
# Epochs 30: accuracy = 0.9621
# Epochs 31: accuracy = 0.9625
# Epochs 32: accuracy = 0.9636
# Epochs 33: accuracy = 0.9638
# Epochs 34: accuracy = 0.9645
# Epochs 35: accuracy = 0.9650
# Epochs 36: accuracy = 0.9661
# Epochs 37: accuracy = 0.9663
# Epochs 38: accuracy = 0.9668
# Epochs 39: accuracy = 0.9670
# Epochs 40: accuracy = 0.9671
# Epochs 41: accuracy = 0.9679
# Epochs 42: accuracy = 0.9679
# Epochs 43: accuracy = 0.9682
# Epochs 44: accuracy = 0.9686
# Epochs 45: accuracy = 0.9688
# Epochs 46: accuracy = 0.9691
# Epochs 47: accuracy = 0.9695
# Epochs 48: accuracy = 0.9696
# Epochs 49: accuracy = 0.9696
# Epochs 50: accuracy = 0.9695
# Epochs 51: accuracy = 0.9698
# Epochs 52: accuracy = 0.9702
# Epochs 53: accuracy = 0.9704
# Epochs 54: accuracy = 0.9709
# Epochs 55: accuracy = 0.9709
# Epochs 56: accuracy = 0.9712
# Epochs 57: accuracy = 0.9714
# Epochs 58: accuracy = 0.9718
# Epochs 59: accuracy = 0.9720
# Epochs 60: accuracy = 0.9727
# Epochs 61: accuracy = 0.9716
# Epochs 62: accuracy = 0.9720
# Epochs 63: accuracy = 0.9716
# Epochs 64: accuracy = 0.9718
# Epochs 65: accuracy = 0.9721
# Epochs 66: accuracy = 0.9714
# Epochs 67: accuracy = 0.9721
# Epochs 68: accuracy = 0.9725
# Epochs 69: accuracy = 0.9727
# Epochs 70: accuracy = 0.9723
# Epochs 71: accuracy = 0.9723
# Epochs 72: accuracy = 0.9723
# Epochs 73: accuracy = 0.9721
# Epochs 74: accuracy = 0.9725
# Epochs 75: accuracy = 0.9725
# Epochs 76: accuracy = 0.9725
# Epochs 77: accuracy = 0.9725
# Epochs 78: accuracy = 0.9725
# Epochs 79: accuracy = 0.9729
# Epochs 80: accuracy = 0.9729
# Epochs 81: accuracy = 0.9730
# Epochs 82: accuracy = 0.9732
# Epochs 83: accuracy = 0.9734
# Epochs 84: accuracy = 0.9734
# Epochs 85: accuracy = 0.9737
# Epochs 86: accuracy = 0.9739
# Epochs 87: accuracy = 0.9746
# Epochs 88: accuracy = 0.9746
# Epochs 89: accuracy = 0.9746
# Epochs 90: accuracy = 0.9748
# Epochs 91: accuracy = 0.9748
# Epochs 92: accuracy = 0.9750
# Epochs 93: accuracy = 0.9754
# Epochs 94: accuracy = 0.9754
# Epochs 95: accuracy = 0.9752
# Epochs 96: accuracy = 0.9755
# Epochs 97: accuracy = 0.9752
# Epochs 98: accuracy = 0.9754
# Epochs 99: accuracy = 0.9755
# Epochs 100: accuracy = 0.9752
# Epochs 101: accuracy = 0.9750
# Epochs 102: accuracy = 0.9752
# Epochs 103: accuracy = 0.9759
# Epochs 104: accuracy = 0.9757
# Epochs 105: accuracy = 0.9755
# Epochs 106: accuracy = 0.9755
# Epochs 107: accuracy = 0.9757
# Epochs 108: accuracy = 0.9757
# Epochs 109: accuracy = 0.9755
# Epochs 110: accuracy = 0.9755
# Epochs 111: accuracy = 0.9761
# Epochs 112: accuracy = 0.9759
# Epochs 113: accuracy = 0.9755
# Epochs 114: accuracy = 0.9755
# Epochs 115: accuracy = 0.9757
# Epochs 116: accuracy = 0.9752
# Epochs 117: accuracy = 0.9754
# Epochs 118: accuracy = 0.9754
# Epochs 119: accuracy = 0.9755
# Epochs 120: accuracy = 0.9752
# Epochs 121: accuracy = 0.9755
# Epochs 122: accuracy = 0.9755
# Epochs 123: accuracy = 0.9759
# Epochs 124: accuracy = 0.9755
# Epochs 125: accuracy = 0.9759
# Epochs 126: accuracy = 0.9755
# Epochs 127: accuracy = 0.9759
# Epochs 128: accuracy = 0.9761
# Epochs 129: accuracy = 0.9759
# Epochs 130: accuracy = 0.9759
# Epochs 131: accuracy = 0.9761
# Epochs 132: accuracy = 0.9768
# Epochs 133: accuracy = 0.9770
# Epochs 134: accuracy = 0.9761
# Epochs 135: accuracy = 0.9770
# Epochs 136: accuracy = 0.9771
# Epochs 137: accuracy = 0.9771
# Epochs 138: accuracy = 0.9766
# Epochs 139: accuracy = 0.9775
# Epochs 140: accuracy = 0.9779
# Epochs 141: accuracy = 0.9771
# Epochs 142: accuracy = 0.9770
# Epochs 143: accuracy = 0.9775
# Epochs 144: accuracy = 0.9771
# Epochs 145: accuracy = 0.9775
# Epochs 146: accuracy = 0.9768
# Epochs 147: accuracy = 0.9773
# Epochs 148: accuracy = 0.9770
# Epochs 149: accuracy = 0.9777
# Epochs 150: accuracy = 0.9766
# Epochs 151: accuracy = 0.9779
# Epochs 152: accuracy = 0.9773
# Epochs 153: accuracy = 0.9771
# Epochs 154: accuracy = 0.9775
# Epochs 155: accuracy = 0.9775
# Epochs 156: accuracy = 0.9770
# Epochs 157: accuracy = 0.9780
# Epochs 158: accuracy = 0.9770
# Epochs 159: accuracy = 0.9773
# Epochs 160: accuracy = 0.9780
# Epochs 161: accuracy = 0.9780
# Epochs 162: accuracy = 0.9784
# Epochs 163: accuracy = 0.9786
# Epochs 164: accuracy = 0.9782
# Epochs 165: accuracy = 0.9786
# Epochs 166: accuracy = 0.9784
# Epochs 167: accuracy = 0.9786
# Epochs 168: accuracy = 0.9784
# Epochs 169: accuracy = 0.9787
# Epochs 170: accuracy = 0.9789
# Epochs 171: accuracy = 0.9789
# Epochs 172: accuracy = 0.9793
# Epochs 173: accuracy = 0.9795
# Epochs 174: accuracy = 0.9786
# Epochs 175: accuracy = 0.9789
# Epochs 176: accuracy = 0.9789
# Epochs 177: accuracy = 0.9798
# Epochs 178: accuracy = 0.9800
# Epochs 179: accuracy = 0.9802
# Epochs 180: accuracy = 0.9805
# Epochs 181: accuracy = 0.9802
# Epochs 182: accuracy = 0.9807
# Epochs 183: accuracy = 0.9802
# Epochs 184: accuracy = 0.9802
# Epochs 185: accuracy = 0.9804
# Epochs 186: accuracy = 0.9811
# Epochs 187: accuracy = 0.9805
# Epochs 188: accuracy = 0.9805
# Epochs 189: accuracy = 0.9807
# Epochs 190: accuracy = 0.9814
# Epochs 191: accuracy = 0.9812
# Epochs 192: accuracy = 0.9811
# Epochs 193: accuracy = 0.9811
# Epochs 194: accuracy = 0.9816
# Epochs 195: accuracy = 0.9812
# Epochs 196: accuracy = 0.9825
# Epochs 197: accuracy = 0.9814
# Epochs 198: accuracy = 0.9825
# Epochs 199: accuracy = 0.9818
# Epochs 200: accuracy = 0.9823
# Epochs 201: accuracy = 0.9821
# Epochs 202: accuracy = 0.9812
# Epochs 203: accuracy = 0.9829
# Epochs 204: accuracy = 0.9821
# Epochs 205: accuracy = 0.9827
# Epochs 206: accuracy = 0.9818
# Epochs 207: accuracy = 0.9823
# Epochs 208: accuracy = 0.9829
# Epochs 209: accuracy = 0.9827
# Epochs 210: accuracy = 0.9827
# Epochs 211: accuracy = 0.9830
# Epochs 212: accuracy = 0.9829
# Epochs 213: accuracy = 0.9829
# Epochs 214: accuracy = 0.9827
# Epochs 215: accuracy = 0.9830
# Epochs 216: accuracy = 0.9834
# Epochs 217: accuracy = 0.9839
# Epochs 218: accuracy = 0.9839
# Epochs 219: accuracy = 0.9837
# Epochs 220: accuracy = 0.9836
# Epochs 221: accuracy = 0.9841
# Epochs 222: accuracy = 0.9837
# Epochs 223: accuracy = 0.9839
# Epochs 224: accuracy = 0.9839
# Epochs 225: accuracy = 0.9845
# Epochs 226: accuracy = 0.9846
# Epochs 227: accuracy = 0.9841
# Epochs 228: accuracy = 0.9837
# Epochs 229: accuracy = 0.9843
# Epochs 230: accuracy = 0.9841
# Epochs 231: accuracy = 0.9850
# Epochs 232: accuracy = 0.9850
# Epochs 233: accuracy = 0.9852
# Epochs 234: accuracy = 0.9852
# Epochs 235: accuracy = 0.9854
# Epochs 236: accuracy = 0.9852
# Epochs 237: accuracy = 0.9852
# Epochs 238: accuracy = 0.9854
# Epochs 239: accuracy = 0.9852
# Epochs 240: accuracy = 0.9857
# Epochs 241: accuracy = 0.9854
# Epochs 242: accuracy = 0.9859
# Epochs 243: accuracy = 0.9857
# Epochs 244: accuracy = 0.9861
# Epochs 245: accuracy = 0.9859
# Epochs 246: accuracy = 0.9862
# Epochs 247: accuracy = 0.9862
# Epochs 248: accuracy = 0.9859
# Epochs 249: accuracy = 0.9862
# Accuracy (wide): 0.99
# Epochs 0: accuracy = 0.8889
# Epochs 1: accuracy = 0.8980
# Epochs 2: accuracy = 0.9064
# Epochs 3: accuracy = 0.9116
# Epochs 4: accuracy = 0.9154
# Epochs 5: accuracy = 0.9198
# Epochs 6: accuracy = 0.9234
# Epochs 7: accuracy = 0.9264
# Epochs 8: accuracy = 0.9293
# Epochs 9: accuracy = 0.9323
# Epochs 10: accuracy = 0.9359
# Epochs 11: accuracy = 0.9411
# Epochs 12: accuracy = 0.9441
# Epochs 13: accuracy = 0.9464
# Epochs 14: accuracy = 0.9480
# Epochs 15: accuracy = 0.9498
# Epochs 16: accuracy = 0.9505
# Epochs 17: accuracy = 0.9525
# Epochs 18: accuracy = 0.9541
# Epochs 19: accuracy = 0.9554
# Epochs 20: accuracy = 0.9568
# Epochs 21: accuracy = 0.9573
# Epochs 22: accuracy = 0.9596
# Epochs 23: accuracy = 0.9607
# Epochs 24: accuracy = 0.9618
# Epochs 25: accuracy = 0.9629
# Epochs 26: accuracy = 0.9638
# Epochs 27: accuracy = 0.9645
# Epochs 28: accuracy = 0.9646
# Epochs 29: accuracy = 0.9650
# Epochs 30: accuracy = 0.9654
# Epochs 31: accuracy = 0.9663
# Epochs 32: accuracy = 0.9668
# Epochs 33: accuracy = 0.9668
# Epochs 34: accuracy = 0.9670
# Epochs 35: accuracy = 0.9677
# Epochs 36: accuracy = 0.9677
# Epochs 37: accuracy = 0.9679
# Epochs 38: accuracy = 0.9675
# Epochs 39: accuracy = 0.9675
# Epochs 40: accuracy = 0.9677
# Epochs 41: accuracy = 0.9673
# Epochs 42: accuracy = 0.9666
# Epochs 43: accuracy = 0.9673
# Epochs 44: accuracy = 0.9679
# Epochs 45: accuracy = 0.9682
# Epochs 46: accuracy = 0.9686
# Epochs 47: accuracy = 0.9688
# Epochs 48: accuracy = 0.9691
# Epochs 49: accuracy = 0.9691
# Epochs 50: accuracy = 0.9698
# Epochs 51: accuracy = 0.9700
# Epochs 52: accuracy = 0.9702
# Epochs 53: accuracy = 0.9707
# Epochs 54: accuracy = 0.9711
# Epochs 55: accuracy = 0.9700
# Epochs 56: accuracy = 0.9702
# Epochs 57: accuracy = 0.9711
# Epochs 58: accuracy = 0.9711
# Epochs 59: accuracy = 0.9714
# Epochs 60: accuracy = 0.9716
# Epochs 61: accuracy = 0.9723
# Epochs 62: accuracy = 0.9721
# Epochs 63: accuracy = 0.9725
# Epochs 64: accuracy = 0.9730
# Epochs 65: accuracy = 0.9727
# Epochs 66: accuracy = 0.9729
# Epochs 67: accuracy = 0.9734
# Epochs 68: accuracy = 0.9741
# Epochs 69: accuracy = 0.9737
# Epochs 70: accuracy = 0.9736
# Epochs 71: accuracy = 0.9739
# Epochs 72: accuracy = 0.9739
# Epochs 73: accuracy = 0.9743
# Epochs 74: accuracy = 0.9741
# Epochs 75: accuracy = 0.9743
# Epochs 76: accuracy = 0.9746
# Epochs 77: accuracy = 0.9741
# Epochs 78: accuracy = 0.9741
# Epochs 79: accuracy = 0.9739
# Epochs 80: accuracy = 0.9745
# Epochs 81: accuracy = 0.9737
# Epochs 82: accuracy = 0.9743
# Epochs 83: accuracy = 0.9736
# Epochs 84: accuracy = 0.9737
# Epochs 85: accuracy = 0.9736
# Epochs 86: accuracy = 0.9734
# Epochs 87: accuracy = 0.9737
# Epochs 88: accuracy = 0.9737
# Epochs 89: accuracy = 0.9739
# Epochs 90: accuracy = 0.9737
# Epochs 91: accuracy = 0.9741
# Epochs 92: accuracy = 0.9748
# Epochs 93: accuracy = 0.9752
# Epochs 94: accuracy = 0.9757
# Epochs 95: accuracy = 0.9754
# Epochs 96: accuracy = 0.9748
# Epochs 97: accuracy = 0.9752
# Epochs 98: accuracy = 0.9748
# Epochs 99: accuracy = 0.9755
# Epochs 100: accuracy = 0.9750
# Epochs 101: accuracy = 0.9752
# Epochs 102: accuracy = 0.9752
# Epochs 103: accuracy = 0.9754
# Epochs 104: accuracy = 0.9754
# Epochs 105: accuracy = 0.9755
# Epochs 106: accuracy = 0.9757
# Epochs 107: accuracy = 0.9755
# Epochs 108: accuracy = 0.9755
# Epochs 109: accuracy = 0.9757
# Epochs 110: accuracy = 0.9755
# Epochs 111: accuracy = 0.9755
# Epochs 112: accuracy = 0.9759
# Epochs 113: accuracy = 0.9764
# Epochs 114: accuracy = 0.9764
# Epochs 115: accuracy = 0.9761
# Epochs 116: accuracy = 0.9762
# Epochs 117: accuracy = 0.9764
# Epochs 118: accuracy = 0.9768
# Epochs 119: accuracy = 0.9770
# Epochs 120: accuracy = 0.9770
# Epochs 121: accuracy = 0.9771
# Epochs 122: accuracy = 0.9770
# Epochs 123: accuracy = 0.9770
# Epochs 124: accuracy = 0.9773
# Epochs 125: accuracy = 0.9773
# Epochs 126: accuracy = 0.9780
# Epochs 127: accuracy = 0.9780
# Epochs 128: accuracy = 0.9780
# Epochs 129: accuracy = 0.9784
# Epochs 130: accuracy = 0.9784
# Epochs 131: accuracy = 0.9782
# Epochs 132: accuracy = 0.9784
# Epochs 133: accuracy = 0.9782
# Epochs 134: accuracy = 0.9780
# Epochs 135: accuracy = 0.9779
# Epochs 136: accuracy = 0.9784
# Epochs 137: accuracy = 0.9786
# Epochs 138: accuracy = 0.9789
# Epochs 139: accuracy = 0.9791
# Epochs 140: accuracy = 0.9791
# Epochs 141: accuracy = 0.9787
# Epochs 142: accuracy = 0.9787
# Epochs 143: accuracy = 0.9791
# Epochs 144: accuracy = 0.9795
# Epochs 145: accuracy = 0.9795
# Epochs 146: accuracy = 0.9796
# Epochs 147: accuracy = 0.9800
# Epochs 148: accuracy = 0.9802
# Epochs 149: accuracy = 0.9804
# Epochs 150: accuracy = 0.9804
# Epochs 151: accuracy = 0.9805
# Epochs 152: accuracy = 0.9805
# Epochs 153: accuracy = 0.9809
# Epochs 154: accuracy = 0.9805
# Epochs 155: accuracy = 0.9807
# Epochs 156: accuracy = 0.9809
# Epochs 157: accuracy = 0.9812
# Epochs 158: accuracy = 0.9816
# Epochs 159: accuracy = 0.9812
# Epochs 160: accuracy = 0.9814
# Epochs 161: accuracy = 0.9811
# Epochs 162: accuracy = 0.9807
# Epochs 163: accuracy = 0.9809
# Epochs 164: accuracy = 0.9814
# Epochs 165: accuracy = 0.9805
# Epochs 166: accuracy = 0.9805
# Epochs 167: accuracy = 0.9816
# Epochs 168: accuracy = 0.9816
# Epochs 169: accuracy = 0.9802
# Epochs 170: accuracy = 0.9818
# Epochs 171: accuracy = 0.9807
# Epochs 172: accuracy = 0.9818
# Epochs 173: accuracy = 0.9809
# Epochs 174: accuracy = 0.9820
# Epochs 175: accuracy = 0.9807
# Epochs 176: accuracy = 0.9811
# Epochs 177: accuracy = 0.9823
# Epochs 178: accuracy = 0.9812
# Epochs 179: accuracy = 0.9814
# Epochs 180: accuracy = 0.9809
# Epochs 181: accuracy = 0.9816
# Epochs 182: accuracy = 0.9816
# Epochs 183: accuracy = 0.9816
# Epochs 184: accuracy = 0.9811
# Epochs 185: accuracy = 0.9818
# Epochs 186: accuracy = 0.9820
# Epochs 187: accuracy = 0.9816
# Epochs 188: accuracy = 0.9821
# Epochs 189: accuracy = 0.9820
# Epochs 190: accuracy = 0.9816
# Epochs 191: accuracy = 0.9820
# Epochs 192: accuracy = 0.9816
# Epochs 193: accuracy = 0.9820
# Epochs 194: accuracy = 0.9818
# Epochs 195: accuracy = 0.9818
# Epochs 196: accuracy = 0.9821
# Epochs 197: accuracy = 0.9818
# Epochs 198: accuracy = 0.9821
# Epochs 199: accuracy = 0.9821
# Epochs 200: accuracy = 0.9821
# Epochs 201: accuracy = 0.9823
# Epochs 202: accuracy = 0.9821
# Epochs 203: accuracy = 0.9821
# Epochs 204: accuracy = 0.9823
# Epochs 205: accuracy = 0.9821
# Epochs 206: accuracy = 0.9827
# Epochs 207: accuracy = 0.9821
# Epochs 208: accuracy = 0.9827
# Epochs 209: accuracy = 0.9821
# Epochs 210: accuracy = 0.9825
# Epochs 211: accuracy = 0.9821
# Epochs 212: accuracy = 0.9827
# Epochs 213: accuracy = 0.9825
# Epochs 214: accuracy = 0.9823
# Epochs 215: accuracy = 0.9825
# Epochs 216: accuracy = 0.9829
# Epochs 217: accuracy = 0.9827
# Epochs 218: accuracy = 0.9829
# Epochs 219: accuracy = 0.9827
# Epochs 220: accuracy = 0.9825
# Epochs 221: accuracy = 0.9825
# Epochs 222: accuracy = 0.9827
# Epochs 223: accuracy = 0.9825
# Epochs 224: accuracy = 0.9825
# Epochs 225: accuracy = 0.9825
# Epochs 226: accuracy = 0.9827
# Epochs 227: accuracy = 0.9829
# Epochs 228: accuracy = 0.9832
# Epochs 229: accuracy = 0.9827
# Epochs 230: accuracy = 0.9832
# Epochs 231: accuracy = 0.9832
# Epochs 232: accuracy = 0.9830
# Epochs 233: accuracy = 0.9830
# Epochs 234: accuracy = 0.9832
# Epochs 235: accuracy = 0.9832
# Epochs 236: accuracy = 0.9834
# Epochs 237: accuracy = 0.9837
# Epochs 238: accuracy = 0.9837
# Epochs 239: accuracy = 0.9837
# Epochs 240: accuracy = 0.9841
# Epochs 241: accuracy = 0.9834
# Epochs 242: accuracy = 0.9843
# Epochs 243: accuracy = 0.9843
# Epochs 244: accuracy = 0.9837
# Epochs 245: accuracy = 0.9841
# Epochs 246: accuracy = 0.9843
# Epochs 247: accuracy = 0.9841
# Epochs 248: accuracy = 0.9839
# Epochs 249: accuracy = 0.9843
# Accuracy (wide): 0.98
# Epochs 0: accuracy = 0.8695
# Epochs 1: accuracy = 0.8879
# Epochs 2: accuracy = 0.8964
# Epochs 3: accuracy = 0.9007
# Epochs 4: accuracy = 0.9038
# Epochs 5: accuracy = 0.9084
# Epochs 6: accuracy = 0.9137
# Epochs 7: accuracy = 0.9173
# Epochs 8: accuracy = 0.9204
# Epochs 9: accuracy = 0.9236
# Epochs 10: accuracy = 0.9262
# Epochs 11: accuracy = 0.9275
# Epochs 12: accuracy = 0.9293
# Epochs 13: accuracy = 0.9304
# Epochs 14: accuracy = 0.9320
# Epochs 15: accuracy = 0.9337
# Epochs 16: accuracy = 0.9359
# Epochs 17: accuracy = 0.9368
# Epochs 18: accuracy = 0.9389
# Epochs 19: accuracy = 0.9395
# Epochs 20: accuracy = 0.9413
# Epochs 21: accuracy = 0.9425
# Epochs 22: accuracy = 0.9448
# Epochs 23: accuracy = 0.9457
# Epochs 24: accuracy = 0.9480
# Epochs 25: accuracy = 0.9489
# Epochs 26: accuracy = 0.9502
# Epochs 27: accuracy = 0.9516
# Epochs 28: accuracy = 0.9525
# Epochs 29: accuracy = 0.9534
# Epochs 30: accuracy = 0.9543
# Epochs 31: accuracy = 0.9552
# Epochs 32: accuracy = 0.9563
# Epochs 33: accuracy = 0.9563
# Epochs 34: accuracy = 0.9573
# Epochs 35: accuracy = 0.9579
# Epochs 36: accuracy = 0.9586
# Epochs 37: accuracy = 0.9595
# Epochs 38: accuracy = 0.9602
# Epochs 39: accuracy = 0.9602
# Epochs 40: accuracy = 0.9607
# Epochs 41: accuracy = 0.9607
# Epochs 42: accuracy = 0.9616
# Epochs 43: accuracy = 0.9625
# Epochs 44: accuracy = 0.9630
# Epochs 45: accuracy = 0.9638
# Epochs 46: accuracy = 0.9643
# Epochs 47: accuracy = 0.9655
# Epochs 48: accuracy = 0.9666
# Epochs 49: accuracy = 0.9670
# Epochs 50: accuracy = 0.9671
# Epochs 51: accuracy = 0.9675
# Epochs 52: accuracy = 0.9677
# Epochs 53: accuracy = 0.9679
# Epochs 54: accuracy = 0.9680
# Epochs 55: accuracy = 0.9688
# Epochs 56: accuracy = 0.9691
# Epochs 57: accuracy = 0.9689
# Epochs 58: accuracy = 0.9698
# Epochs 59: accuracy = 0.9707
# Epochs 60: accuracy = 0.9718
# Epochs 61: accuracy = 0.9721
# Epochs 62: accuracy = 0.9727
# Epochs 63: accuracy = 0.9729
# Epochs 64: accuracy = 0.9732
# Epochs 65: accuracy = 0.9741
# Epochs 66: accuracy = 0.9741
# Epochs 67: accuracy = 0.9743
# Epochs 68: accuracy = 0.9743
# Epochs 69: accuracy = 0.9746
# Epochs 70: accuracy = 0.9746
# Epochs 71: accuracy = 0.9754
# Epochs 72: accuracy = 0.9755
# Epochs 73: accuracy = 0.9757
# Epochs 74: accuracy = 0.9754
# Epochs 75: accuracy = 0.9754
# Epochs 76: accuracy = 0.9757
# Epochs 77: accuracy = 0.9761
# Epochs 78: accuracy = 0.9770
# Epochs 79: accuracy = 0.9768
# Epochs 80: accuracy = 0.9771
# Epochs 81: accuracy = 0.9779
# Epochs 82: accuracy = 0.9780
# Epochs 83: accuracy = 0.9786
# Epochs 84: accuracy = 0.9787
# Epochs 85: accuracy = 0.9795
# Epochs 86: accuracy = 0.9791
# Epochs 87: accuracy = 0.9795
# Epochs 88: accuracy = 0.9798
# Epochs 89: accuracy = 0.9800
# Epochs 90: accuracy = 0.9800
# Epochs 91: accuracy = 0.9800
# Epochs 92: accuracy = 0.9804
# Epochs 93: accuracy = 0.9802
# Epochs 94: accuracy = 0.9804
# Epochs 95: accuracy = 0.9802
# Epochs 96: accuracy = 0.9811
# Epochs 97: accuracy = 0.9809
# Epochs 98: accuracy = 0.9814
# Epochs 99: accuracy = 0.9816
# Epochs 100: accuracy = 0.9816
# Epochs 101: accuracy = 0.9816
# Epochs 102: accuracy = 0.9821
# Epochs 103: accuracy = 0.9821
# Epochs 104: accuracy = 0.9821
# Epochs 105: accuracy = 0.9827
# Epochs 106: accuracy = 0.9825
# Epochs 107: accuracy = 0.9823
# Epochs 108: accuracy = 0.9827
# Epochs 109: accuracy = 0.9825
# Epochs 110: accuracy = 0.9825
# Epochs 111: accuracy = 0.9829
# Epochs 112: accuracy = 0.9830
# Epochs 113: accuracy = 0.9827
# Epochs 114: accuracy = 0.9830
# Epochs 115: accuracy = 0.9829
# Epochs 116: accuracy = 0.9825
# Epochs 117: accuracy = 0.9830
# Epochs 118: accuracy = 0.9827
# Epochs 119: accuracy = 0.9834
# Epochs 120: accuracy = 0.9832
# Epochs 121: accuracy = 0.9836
# Epochs 122: accuracy = 0.9841
# Epochs 123: accuracy = 0.9836
# Epochs 124: accuracy = 0.9846
# Epochs 125: accuracy = 0.9841
# Epochs 126: accuracy = 0.9837
# Epochs 127: accuracy = 0.9846
# Epochs 128: accuracy = 0.9839
# Epochs 129: accuracy = 0.9846
# Epochs 130: accuracy = 0.9841
# Epochs 131: accuracy = 0.9850
# Epochs 132: accuracy = 0.9845
# Epochs 133: accuracy = 0.9846
# Epochs 134: accuracy = 0.9848
# Epochs 135: accuracy = 0.9852
# Epochs 136: accuracy = 0.9850
# Epochs 137: accuracy = 0.9854
# Epochs 138: accuracy = 0.9854
# Epochs 139: accuracy = 0.9857
# Epochs 140: accuracy = 0.9855
# Epochs 141: accuracy = 0.9857
# Epochs 142: accuracy = 0.9855
# Epochs 143: accuracy = 0.9854
# Epochs 144: accuracy = 0.9861
# Epochs 145: accuracy = 0.9861
# Epochs 146: accuracy = 0.9868
# Epochs 147: accuracy = 0.9868
# Epochs 148: accuracy = 0.9868
# Epochs 149: accuracy = 0.9868
# Epochs 150: accuracy = 0.9866
# Epochs 151: accuracy = 0.9868
# Epochs 152: accuracy = 0.9868
# Epochs 153: accuracy = 0.9868
# Epochs 154: accuracy = 0.9873
# Epochs 155: accuracy = 0.9875
# Epochs 156: accuracy = 0.9873
# Epochs 157: accuracy = 0.9873
# Epochs 158: accuracy = 0.9873
# Epochs 159: accuracy = 0.9873
# Epochs 160: accuracy = 0.9875
# Epochs 161: accuracy = 0.9873
# Epochs 162: accuracy = 0.9873
# Epochs 163: accuracy = 0.9873
# Epochs 164: accuracy = 0.9877
# Epochs 165: accuracy = 0.9877
# Epochs 166: accuracy = 0.9877
# Epochs 167: accuracy = 0.9877
# Epochs 168: accuracy = 0.9879
# Epochs 169: accuracy = 0.9879
# Epochs 170: accuracy = 0.9879
# Epochs 171: accuracy = 0.9880
# Epochs 172: accuracy = 0.9879
# Epochs 173: accuracy = 0.9879
# Epochs 174: accuracy = 0.9871
# Epochs 175: accuracy = 0.9879
# Epochs 176: accuracy = 0.9877
# Epochs 177: accuracy = 0.9877
# Epochs 178: accuracy = 0.9879
# Epochs 179: accuracy = 0.9877
# Epochs 180: accuracy = 0.9886
# Epochs 181: accuracy = 0.9879
# Epochs 182: accuracy = 0.9884
# Epochs 183: accuracy = 0.9882
# Epochs 184: accuracy = 0.9884
# Epochs 185: accuracy = 0.9884
# Epochs 186: accuracy = 0.9887
# Epochs 187: accuracy = 0.9884
# Epochs 188: accuracy = 0.9889
# Epochs 189: accuracy = 0.9884
# Epochs 190: accuracy = 0.9891
# Epochs 191: accuracy = 0.9882
# Epochs 192: accuracy = 0.9891
# Epochs 193: accuracy = 0.9884
# Epochs 194: accuracy = 0.9893
# Epochs 195: accuracy = 0.9887
# Epochs 196: accuracy = 0.9887
# Epochs 197: accuracy = 0.9891
# Epochs 198: accuracy = 0.9891
# Epochs 199: accuracy = 0.9891
# Epochs 200: accuracy = 0.9887
# Epochs 201: accuracy = 0.9891
# Epochs 202: accuracy = 0.9895
# Epochs 203: accuracy = 0.9891
# Epochs 204: accuracy = 0.9895
# Epochs 205: accuracy = 0.9891
# Epochs 206: accuracy = 0.9895
# Epochs 207: accuracy = 0.9887
# Epochs 208: accuracy = 0.9893
# Epochs 209: accuracy = 0.9891
# Epochs 210: accuracy = 0.9895
# Epochs 211: accuracy = 0.9889
# Epochs 212: accuracy = 0.9893
# Epochs 213: accuracy = 0.9889
# Epochs 214: accuracy = 0.9895
# Epochs 215: accuracy = 0.9887
# Epochs 216: accuracy = 0.9896
# Epochs 217: accuracy = 0.9889
# Epochs 218: accuracy = 0.9895
# Epochs 219: accuracy = 0.9893
# Epochs 220: accuracy = 0.9896
# Epochs 221: accuracy = 0.9895
# Epochs 222: accuracy = 0.9893
# Epochs 223: accuracy = 0.9891
# Epochs 224: accuracy = 0.9893
# Epochs 225: accuracy = 0.9893
# Epochs 226: accuracy = 0.9895
# Epochs 227: accuracy = 0.9891
# Epochs 228: accuracy = 0.9898
# Epochs 229: accuracy = 0.9900
# Epochs 230: accuracy = 0.9895
# Epochs 231: accuracy = 0.9889
# Epochs 232: accuracy = 0.9896
# Epochs 233: accuracy = 0.9891
# Epochs 234: accuracy = 0.9898
# Epochs 235: accuracy = 0.9896
# Epochs 236: accuracy = 0.9893
# Epochs 237: accuracy = 0.9896
# Epochs 238: accuracy = 0.9893
# Epochs 239: accuracy = 0.9895
# Epochs 240: accuracy = 0.9893
# Epochs 241: accuracy = 0.9893
# Epochs 242: accuracy = 0.9896
# Epochs 243: accuracy = 0.9895
# Epochs 244: accuracy = 0.9893
# Epochs 245: accuracy = 0.9893
# Epochs 246: accuracy = 0.9895
# Epochs 247: accuracy = 0.9891
# Epochs 248: accuracy = 0.9891
# Epochs 249: accuracy = 0.9895
# Accuracy (wide): 0.99
# Epochs 0: accuracy = 0.8838
# Epochs 1: accuracy = 0.8923
# Epochs 2: accuracy = 0.9005
# Epochs 3: accuracy = 0.9052
# Epochs 4: accuracy = 0.9111
# Epochs 5: accuracy = 0.9136
# Epochs 6: accuracy = 0.9164
# Epochs 7: accuracy = 0.9186
# Epochs 8: accuracy = 0.9216
# Epochs 9: accuracy = 0.9243
# Epochs 10: accuracy = 0.9287
# Epochs 11: accuracy = 0.9305
# Epochs 12: accuracy = 0.9318
# Epochs 13: accuracy = 0.9337
# Epochs 14: accuracy = 0.9361
# Epochs 15: accuracy = 0.9373
# Epochs 16: accuracy = 0.9386
# Epochs 17: accuracy = 0.9404
# Epochs 18: accuracy = 0.9418
# Epochs 19: accuracy = 0.9430
# Epochs 20: accuracy = 0.9438
# Epochs 21: accuracy = 0.9455
# Epochs 22: accuracy = 0.9466
# Epochs 23: accuracy = 0.9480
# Epochs 24: accuracy = 0.9489
# Epochs 25: accuracy = 0.9511
# Epochs 26: accuracy = 0.9516
# Epochs 27: accuracy = 0.9525
# Epochs 28: accuracy = 0.9530
# Epochs 29: accuracy = 0.9538
# Epochs 30: accuracy = 0.9538
# Epochs 31: accuracy = 0.9545
# Epochs 32: accuracy = 0.9563
# Epochs 33: accuracy = 0.9568
# Epochs 34: accuracy = 0.9580
# Epochs 35: accuracy = 0.9588
# Epochs 36: accuracy = 0.9591
# Epochs 37: accuracy = 0.9598
# Epochs 38: accuracy = 0.9596
# Epochs 39: accuracy = 0.9602
# Epochs 40: accuracy = 0.9623
# Epochs 41: accuracy = 0.9623
# Epochs 42: accuracy = 0.9632
# Epochs 43: accuracy = 0.9632
# Epochs 44: accuracy = 0.9641
# Epochs 45: accuracy = 0.9646
# Epochs 46: accuracy = 0.9657
# Epochs 47: accuracy = 0.9663
# Epochs 48: accuracy = 0.9671
# Epochs 49: accuracy = 0.9670
# Epochs 50: accuracy = 0.9675
# Epochs 51: accuracy = 0.9673
# Epochs 52: accuracy = 0.9677
# Epochs 53: accuracy = 0.9679
# Epochs 54: accuracy = 0.9673
# Epochs 55: accuracy = 0.9675
# Epochs 56: accuracy = 0.9679
# Epochs 57: accuracy = 0.9682
# Epochs 58: accuracy = 0.9688
# Epochs 59: accuracy = 0.9689
# Epochs 60: accuracy = 0.9689
# Epochs 61: accuracy = 0.9686
# Epochs 62: accuracy = 0.9689
# Epochs 63: accuracy = 0.9688
# Epochs 64: accuracy = 0.9684
# Epochs 65: accuracy = 0.9688
# Epochs 66: accuracy = 0.9689
# Epochs 67: accuracy = 0.9689
# Epochs 68: accuracy = 0.9689
# Epochs 69: accuracy = 0.9689
# Epochs 70: accuracy = 0.9689
# Epochs 71: accuracy = 0.9686
# Epochs 72: accuracy = 0.9693
# Epochs 73: accuracy = 0.9691
# Epochs 74: accuracy = 0.9693
# Epochs 75: accuracy = 0.9698
# Epochs 76: accuracy = 0.9700
# Epochs 77: accuracy = 0.9704
# Epochs 78: accuracy = 0.9707
# Epochs 79: accuracy = 0.9711
# Epochs 80: accuracy = 0.9716
# Epochs 81: accuracy = 0.9720
# Epochs 82: accuracy = 0.9721
# Epochs 83: accuracy = 0.9727
# Epochs 84: accuracy = 0.9727
# Epochs 85: accuracy = 0.9730
# Epochs 86: accuracy = 0.9730
# Epochs 87: accuracy = 0.9734
# Epochs 88: accuracy = 0.9736
# Epochs 89: accuracy = 0.9741
# Epochs 90: accuracy = 0.9743
# Epochs 91: accuracy = 0.9743
# Epochs 92: accuracy = 0.9743
# Epochs 93: accuracy = 0.9745
# Epochs 94: accuracy = 0.9745
# Epochs 95: accuracy = 0.9745
# Epochs 96: accuracy = 0.9750
# Epochs 97: accuracy = 0.9750
# Epochs 98: accuracy = 0.9752
# Epochs 99: accuracy = 0.9754
# Epochs 100: accuracy = 0.9754
# Epochs 101: accuracy = 0.9754
# Epochs 102: accuracy = 0.9754
# Epochs 103: accuracy = 0.9757
# Epochs 104: accuracy = 0.9757
# Epochs 105: accuracy = 0.9757
# Epochs 106: accuracy = 0.9755
# Epochs 107: accuracy = 0.9755
# Epochs 108: accuracy = 0.9755
# Epochs 109: accuracy = 0.9757
# Epochs 110: accuracy = 0.9754
# Epochs 111: accuracy = 0.9754
# Epochs 112: accuracy = 0.9759
# Epochs 113: accuracy = 0.9762
# Epochs 114: accuracy = 0.9762
# Epochs 115: accuracy = 0.9761
# Epochs 116: accuracy = 0.9762
# Epochs 117: accuracy = 0.9766
# Epochs 118: accuracy = 0.9762
# Epochs 119: accuracy = 0.9766
# Epochs 120: accuracy = 0.9766
# Epochs 121: accuracy = 0.9766
# Epochs 122: accuracy = 0.9766
# Epochs 123: accuracy = 0.9770
# Epochs 124: accuracy = 0.9770
# Epochs 125: accuracy = 0.9771
# Epochs 126: accuracy = 0.9775
# Epochs 127: accuracy = 0.9775
# Epochs 128: accuracy = 0.9771
# Epochs 129: accuracy = 0.9775
# Epochs 130: accuracy = 0.9775
# Epochs 131: accuracy = 0.9773
# Epochs 132: accuracy = 0.9777
# Epochs 133: accuracy = 0.9775
# Epochs 134: accuracy = 0.9771
# Epochs 135: accuracy = 0.9773
# Epochs 136: accuracy = 0.9768
# Epochs 137: accuracy = 0.9768
# Epochs 138: accuracy = 0.9764
# Epochs 139: accuracy = 0.9762
# Epochs 140: accuracy = 0.9764
# Epochs 141: accuracy = 0.9766
# Epochs 142: accuracy = 0.9768
# Epochs 143: accuracy = 0.9766
# Epochs 144: accuracy = 0.9761
# Epochs 145: accuracy = 0.9766
# Epochs 146: accuracy = 0.9766
# Epochs 147: accuracy = 0.9768
# Epochs 148: accuracy = 0.9766
# Epochs 149: accuracy = 0.9770
# Epochs 150: accuracy = 0.9768
# Epochs 151: accuracy = 0.9768
# Epochs 152: accuracy = 0.9768
# Epochs 153: accuracy = 0.9770
# Epochs 154: accuracy = 0.9771
# Epochs 155: accuracy = 0.9771
# Epochs 156: accuracy = 0.9775
# Epochs 157: accuracy = 0.9777
# Epochs 158: accuracy = 0.9777
# Epochs 159: accuracy = 0.9779
# Epochs 160: accuracy = 0.9779
# Epochs 161: accuracy = 0.9779
# Epochs 162: accuracy = 0.9779
# Epochs 163: accuracy = 0.9777
# Epochs 164: accuracy = 0.9782
# Epochs 165: accuracy = 0.9782
# Epochs 166: accuracy = 0.9782
# Epochs 167: accuracy = 0.9782
# Epochs 168: accuracy = 0.9784
# Epochs 169: accuracy = 0.9784
# Epochs 170: accuracy = 0.9787
# Epochs 171: accuracy = 0.9789
# Epochs 172: accuracy = 0.9786
# Epochs 173: accuracy = 0.9786
# Epochs 174: accuracy = 0.9786
# Epochs 175: accuracy = 0.9782
# Epochs 176: accuracy = 0.9782
# Epochs 177: accuracy = 0.9786
# Epochs 178: accuracy = 0.9789
# Epochs 179: accuracy = 0.9791
# Epochs 180: accuracy = 0.9795
# Epochs 181: accuracy = 0.9793
# Epochs 182: accuracy = 0.9795
# Epochs 183: accuracy = 0.9793
# Epochs 184: accuracy = 0.9800
# Epochs 185: accuracy = 0.9798
# Epochs 186: accuracy = 0.9798
# Epochs 187: accuracy = 0.9798
# Epochs 188: accuracy = 0.9807
# Epochs 189: accuracy = 0.9804
# Epochs 190: accuracy = 0.9798
# Epochs 191: accuracy = 0.9804
# Epochs 192: accuracy = 0.9804
# Epochs 193: accuracy = 0.9805
# Epochs 194: accuracy = 0.9804
# Epochs 195: accuracy = 0.9804
# Epochs 196: accuracy = 0.9805
# Epochs 197: accuracy = 0.9809
# Epochs 198: accuracy = 0.9809
# Epochs 199: accuracy = 0.9807
# Epochs 200: accuracy = 0.9809
# Epochs 201: accuracy = 0.9809
# Epochs 202: accuracy = 0.9811
# Epochs 203: accuracy = 0.9809
# Epochs 204: accuracy = 0.9811
# Epochs 205: accuracy = 0.9811
# Epochs 206: accuracy = 0.9811
# Epochs 207: accuracy = 0.9809
# Epochs 208: accuracy = 0.9809
# Epochs 209: accuracy = 0.9805
# Epochs 210: accuracy = 0.9807
# Epochs 211: accuracy = 0.9805
# Epochs 212: accuracy = 0.9802
# Epochs 213: accuracy = 0.9798
# Epochs 214: accuracy = 0.9800
# Epochs 215: accuracy = 0.9802
# Epochs 216: accuracy = 0.9805
# Epochs 217: accuracy = 0.9805
# Epochs 218: accuracy = 0.9807
# Epochs 219: accuracy = 0.9807
# Epochs 220: accuracy = 0.9804
# Epochs 221: accuracy = 0.9805
# Epochs 222: accuracy = 0.9805
# Epochs 223: accuracy = 0.9805
# Epochs 224: accuracy = 0.9809
# Epochs 225: accuracy = 0.9805
# Epochs 226: accuracy = 0.9809
# Epochs 227: accuracy = 0.9809
# Epochs 228: accuracy = 0.9812
# Epochs 229: accuracy = 0.9809
# Epochs 230: accuracy = 0.9811
# Epochs 231: accuracy = 0.9811
# Epochs 232: accuracy = 0.9811
# Epochs 233: accuracy = 0.9812
# Epochs 234: accuracy = 0.9811
# Epochs 235: accuracy = 0.9812
# Epochs 236: accuracy = 0.9812
# Epochs 237: accuracy = 0.9814
# Epochs 238: accuracy = 0.9816
# Epochs 239: accuracy = 0.9814
# Epochs 240: accuracy = 0.9809
# Epochs 241: accuracy = 0.9816
# Epochs 242: accuracy = 0.9814
# Epochs 243: accuracy = 0.9814
# Epochs 244: accuracy = 0.9816
# Epochs 245: accuracy = 0.9816
# Epochs 246: accuracy = 0.9816
# Epochs 247: accuracy = 0.9812
# Epochs 248: accuracy = 0.9816
# Epochs 249: accuracy = 0.9812
# Accuracy (wide): 0.98
# Wide: 98.42% (+/- 0.38%)

# %%
y_pred = model(X_train)
y_pred = y_pred.round()
y_pred
# Out:
# tensor([[0.],
#         [1.],
#         [1.],
#         ...,
#         [0.],
#         [0.],
#         [0.]], grad_fn=<RoundBackward0>)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(X_train[y_train[:, 0] == 1, 0], X_train[y_train[:, 0] == 1, 1], 'ro', label='1')
plt.plot(X_train[y_train[:, 0] == 0, 0], X_train[y_train[:, 0] == 0, 1], 'bo', label='0')
plt.legend()

# %%
plt.figure()
plt.plot(X_train[y_pred[:, 0] == 1, 0], X_train[y_pred[:, 0] == 1, 1], 'ro', label='1')
plt.plot(X_train[y_pred[:, 0] == 0, 0], X_train[y_pred[:, 0] == 0, 1], 'bo', label='0')
plt.legend()

# %%
# save the model
torch.save(model.state_dict(), "deep_model.pth")
